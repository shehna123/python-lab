# %%
a=int(input("enter first number"))
b=int(input("enter second number"))
c=a+b
print(c)
# Out:
# enter first number5
# enter second number6
# 11

# %%
name=input("enter your name")
age=int(input("enter age"))
mark=float(input("enter mark"))
print(name)
print(age)
print(mark)
# Out:
# enter your nameshehna
# enter age21
# enter mark65
# shehna
# 21
# 65.0
